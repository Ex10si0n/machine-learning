# %%
x = [1, 2, 4, 4, 5, 6, 9, 9, 9, 10]
y = [4, 5, 8, 12, 15, 16, 18, 21, 22, 24]

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.scatter(x, y)
x_line = np.linspace(0,10,100)
plt.plot(x_line, 2.310601 * x_line + 0.599747, '-r', label='y=2x+1')
plt.show()
